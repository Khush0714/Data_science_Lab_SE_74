# %% [markdown]
# <a href="https://colab.research.google.com/github/Khush0714/Data_science_Lab_SE_74/blob/main/practical4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MEAN, MEDIAN, MODE

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Take numbers from user
data = list(map(float, input("Enter exactly two numbers separated by space: ").split()))

# Convert list to numpy array
data = np.array(data)

# Calculate mean, median and mode
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)[0]

# Print results
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Enter exactly two numbers separated by space: 10 15 20 20 25 30 35 40 40 45
# Mean: 28.0
# Median: 27.5
# Mode: 20.0

# %% [markdown]
# VARIENCE

# %%
# Compute variance
variance_value = np.var(data)
print(f"Variance: {variance_value:.2f}")
# Out:
# Variance: 126.00

# %% [markdown]
# STANDARD DEVIATION

# %%
# Compute standard deviation
std_dev_value = np.std(data)
print(f"Standard Deviation: {std_dev_value:.2f}")
# Out:
# Standard Deviation: 11.22

# %% [markdown]
# NORAMAL DISTRIBUTATION GRAPH

# %%
# Generate x values
x = np.linspace(min(data), max(data), 100)

# Calculate probability density
y = stats.norm.pdf(x, mean, std_dev_value)

# Plot graph
plt.plot(x, y)
plt.title("Normal Distribution")
plt.xlabel("Values")
plt.ylabel("Probability Density")
plt.show()

# %%
plt.hist(data, bins=15, density=True, alpha=0.6, color='g', label='Data Histogram')

# Add labels and title
plt.title("Normal Distribution with Histogram")
plt.xlabel("Values")
plt.ylabel("Probability Density")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# COIN TOSS SIMULATION

# %%
# Take number of tosses from user
n = int(input("Enter number of coin tosses: "))

# Simulate coin toss
tosses = np.random.choice(['Head', 'Tail'], size=n)

# Count results
heads = np.sum(tosses == 'Head')
tails = np.sum(tosses == 'Tail')

# Display results
print("Heads:", heads)
print("Tails:", tails)

# Calculate probability
print("Probability of Heads:", heads/n)
print("Probability of Tails:", tails/n)
# Out:
# Enter number of coin tosses: 1
# Heads: 0
# Tails: 1
# Probability of Heads: 0.0
# Probability of Tails: 1.0
